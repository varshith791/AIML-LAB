# %% [markdown]
# <a href="https://colab.research.google.com/github/varshith791/AIML-LAB/blob/main/nnfL_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scikit-fuzzy
import numpy as np
import matplotlib.pyplot as plt
import skfuzzy as fuzz

# Define the range for the universe of discourse
x = np.arange(0, 40, 0.1)

# Define fuzzy set "Cold" using a trapezoidal membership function
cold = fuzz.trapmf(x, [0, 0, 10, 15])

# Define fuzzy set "Warm" using a trapezoidal membership function
warm = fuzz.trapmf(x, [10, 20, 25, 30])

# Define fuzzy set "Hot" using a trapezoidal membership function
hot = fuzz.trapmf(x, [25, 30, 40, 40])

# Plot fuzzy sets "Cold", "Warm", and "Hot"
plt.figure(figsize=(12, 6))
plt.plot(x, cold, label='Cold', linewidth=2)
plt.plot(x, warm, label='Warm', linewidth=2)
plt.plot(x, hot, label='Hot', linewidth=2)
plt.xlabel('Temperature (°C)')
plt.ylabel('Membership Degree')
plt.title('Fuzzy Sets for Temperature Levels')
plt.legend()
plt.grid(True)
plt.show()

# %%
# !pip install scikit-fuzzy

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt

# Define the range of speed values
x_speed = np.arange(0, 121, 1)

# Define the fuzzy membership functions for Slow, Medium, and Fast
slow = fuzz.trapmf(x_speed, [0, 0, 20, 40])
medium = fuzz.trimf(x_speed, [30, 50, 70])
fast = fuzz.trapmf(x_speed, [60, 80, 120, 120])

# Plotting the membership functions
plt.figure(figsize=(10, 6))

plt.plot(x_speed, slow, 'b', linewidth=1.5, label='Slow')
plt.plot(x_speed, medium, 'g', linewidth=1.5, label='Medium')
plt.plot(x_speed, fast, 'r', linewidth=1.5, label='Fast')
plt.title('Speed Classification')
plt.xlabel('Speed (km/h)')
plt.ylabel('Membership Degree')
plt.legend()

plt.grid(True)
plt.show()

# Example of evaluating a specific speed
speed_value = 65  # You can change this value to test different speeds

# Get the degree of membership for each fuzzy set
slow_degree = fuzz.interp_membership(x_speed, slow, speed_value)
medium_degree = fuzz.interp_membership(x_speed, medium, speed_value)
fast_degree = fuzz.interp_membership(x_speed, fast, speed_value)

print(f"Speed: {speed_value} km/h")
print(f"Slow: {slow_degree:.2f}")
print(f"Medium: {medium_degree:.2f}")
print(f"Fast: {fast_degree:.2f}")
# Out:
# Speed: 65 km/h
# Slow: 0.00
# Medium: 0.25
# Fast: 0.25

# %%
#Fuzzy Logic Classification of Height Using Trapezoidal and Triangular Membership Functions

import numpy as np
import matplotlib.pyplot as plt

# Define the range for the universe of discourse (Height in cm)
x = np.arange(100, 200, 0.1)

# Define a trapezoidal membership function manually
def trapezoidal_mf(x, a, b, c, d):
    return np.maximum(0, np.minimum((x - a) / (b - a), np.minimum(1, (d - x) / (d - c))))

# Define fuzzy set "Short" using a manually defined trapezoidal membership function
short = trapezoidal_mf(x, 100, 120, 140, 160)

# Define fuzzy set "Average" using a manually defined triangular membership function
def triangular_mf(x, a, b, c):
    return np.maximum(0, np.minimum((x - a) / (b - a), (c - x) / (c - b)))

average = triangular_mf(x, 140, 160, 180)

# Define fuzzy set "Tall" using a manually defined trapezoidal membership function
# Adjust the parameters to avoid division by zero
tall = trapezoidal_mf(x, 160, 180, 190, 200)

# Plot fuzzy sets "Short", "Average", and "Tall"
plt.figure(figsize=(12, 6))
plt.plot(x, short, label='Short', linewidth=2)
plt.plot(x, average, label='Average', linewidth=2)
plt.plot(x, tall, label='Tall', linewidth=2)
plt.xlabel('Height (cm)')
plt.ylabel('Membership Degree')
plt.title('Fuzzy Sets for Height Levels')
plt.legend()
plt.grid(True)
plt.show()

# Evaluate a specific height
test_height = 165  # Example height value
membership_short = trapezoidal_mf(test_height, 100, 120, 140, 160)
membership_average = triangular_mf(test_height, 140, 160, 180)
membership_tall = trapezoidal_mf(test_height, 160, 180, 190, 200)

print(f'For a height of {test_height} cm:')
print(f'Membership degree in Short: {membership_short:.2f}')
print(f'Membership degree in Average: {membership_average:.2f}')
print(f'Membership degree in Tall: {membership_tall:.2f}')

# Visualize the membership degrees for the specific height
plt.figure(figsize=(12, 6))
plt.plot(x, short, label='Short', linewidth=2)
plt.plot(x, average, label='Average', linewidth=2)
plt.plot(x, tall, label='Tall', linewidth=2)
plt.axvline(x=test_height, color='r', linestyle='--', label=f'Test Height: {test_height} cm')
plt.xlabel('Height (cm)')
plt.ylabel('Membership Degree')
plt.title('Membership Degrees for Test Height')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For a height of 165 cm:
# Membership degree in Short: 0.00
# Membership degree in Average: 0.75
# Membership degree in Tall: 0.25
